# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('log.csv')
imu_df = pd.read_csv('imu_log.csv')
vision_df = pd.read_csv('vision_log.csv')

# %%
df['timestamp'] = df['timestamp'] - df['timestamp'].min()

# %%
df.head()
# Out:
#    timestamp   event        qx        qy        qz        qw        px  \
# 0   0.000000  vision  0.007541  0.002047 -0.000152  0.999969 -0.000097
# 1   0.031487  vision  0.007533  0.002066 -0.000086  0.999969  0.000060
# 2   0.055348     imu  0.007535  0.002071 -0.000152  0.999969  0.000065
# 3   0.060186     imu  0.007536  0.002074 -0.000164  0.999969  0.000067
# 4   0.062940  vision  0.007569  0.002122 -0.000051  0.999969  0.000088
#
#          py        pz        vx        vy        vz      b_ax      b_ay  \
# 0  0.000064 -0.000008  0.000000  0.000000  0.000000 -0.000000  0.000000
# 1  0.000011  0.000022  0.000000  0.000000  0.000000 -0.000000  0.000000
# 2  0.000006  0.000023  0.000442 -0.000376  0.000069 -0.000000  0.000000
# 3  0.000004  0.000023  0.000531 -0.000452  0.000083 -0.000000  0.000000
# 4 -0.000045  0.000078  0.000751 -0.000096  0.000305 -0.000012 -0.000022
#
#        b_az      b_gx      b_gy      b_gz
# 0 -0.012182  0.001979  0.000251  0.003496
# 1 -0.012182  0.001979  0.000251  0.003496
# 2 -0.012182  0.001979  0.000251  0.003496
# 3 -0.012182  0.001979  0.000251  0.003496
# 4 -0.012211  0.001977  0.000256  0.003487

# %%
# %matplotlib ipympl
plt.close('all')

fig, ax = plt.subplots(1, 1)
for col_name in ['px', 'py', 'pz']:
    ax.plot(df['timestamp'], df[col_name], marker=None, label=col_name)

ax.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
plt.close('all')

fig, ax = plt.subplots(1, 1)
for col_name in ['b_ax', 'b_ay', 'b_az']:
    ax.plot(df['timestamp'], df[col_name], marker=None, label=col_name)

ax.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
plt.close('all')

fig, ax = plt.subplots(1, 1)
for col_name in ['b_gx', 'b_gy', 'b_gz']:
    ax.plot(df['timestamp'], df[col_name], marker=None, label=col_name)

ax.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
plt.close('all')

fig, ax = plt.subplots(1, 1)
for col_name in ['qx', 'qy', 'qz']:
    ax.plot(df['timestamp'], df[col_name], marker=None, label=col_name)

ax.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
for col_name in 'ax', 'ay', 'az':
    print(f"{col_name}: mean: {imu_df[col_name].mean()}, std: {imu_df[col_name].std()}")
# Out:
# ax: mean: -0.009340156488549618, std: 0.003633270078846185
# ay: mean: 0.13220202290076336, std: 0.003038382302909006
# az: mean: 9.81309575572519, std: 0.0036045364597305195
