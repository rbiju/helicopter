# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('log.csv')
imu_df = pd.read_csv('imu_log.csv')
vision_df = pd.read_csv('vision_log.csv')

# %%
df['timestamp'] = df['timestamp'] - df['timestamp'].min()

# %%
df.head()
# Out:
#    timestamp   event        qw        qx        qy        qz        px   py  \
# 0   0.000000  vision  0.999603  0.006739  0.027350  0.000000  0.000000  0.0
# 1   0.016621  vision  0.999603  0.006739  0.027350  0.000000  0.000000  0.0
# 2   0.033239  vision  0.999603  0.006739  0.027350  0.000000  0.000000  0.0
# 3   0.040808     imu  0.999603  0.006784  0.027353  0.000025  0.000012  0.0
# 4   0.045810     imu  0.999603  0.006793  0.027353  0.000024  0.000018  0.0
#
#     pz        vx        vy        vz  b_ax  b_ay      b_az      b_gx  \
# 0  0.0  0.000000  0.000000  0.000000   0.0  -0.0 -0.008333  0.002009
# 1  0.0  0.000000  0.000000  0.000000   0.0  -0.0 -0.008333  0.002009
# 2  0.0  0.000000  0.000000  0.000000   0.0  -0.0 -0.008333  0.002009
# 3  0.0  0.000995  0.000028  0.000014   0.0  -0.0 -0.008333  0.002009
# 4  0.0  0.001174  0.000029 -0.000003   0.0  -0.0 -0.008333  0.002009
#
#        b_gy      b_gz
# 0  0.000219  0.003448
# 1  0.000219  0.003448
# 2  0.000219  0.003448
# 3  0.000219  0.003448
# 4  0.000219  0.003448

# %%
# %matplotlib ipympl
plt.close('all')

fig, ax = plt.subplots(1, 1)
for col_name in ['px', 'py', 'pz']:
    ax.plot(df['timestamp'], df[col_name], marker=None, label=col_name)

ax.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
plt.close('all')

fig, ax = plt.subplots(1, 1)
for col_name in ['b_ax', 'b_ay', 'b_az']:
    ax.plot(df['timestamp'], df[col_name], marker=None, label=col_name)

ax.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
plt.close('all')

fig, ax = plt.subplots(1, 1)
for col_name in ['qx', 'qy', 'qz']:
    ax.plot(df['timestamp'], df[col_name], marker=None, label=col_name)

ax.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
for col_name in 'ax', 'ay', 'az':
    print(f"{col_name}: mean: {imu_df[col_name].mean()}, std: {imu_df[col_name].std()}")
# Out:
# ax: mean: -0.1131586296109146, std: 0.0046019966240709
# ay: mean: 0.1536800808489136, std: 0.003132644623838458
# az: mean: 9.787734914098028, std: 0.0036631872171878437
