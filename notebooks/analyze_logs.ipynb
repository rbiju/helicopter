# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('log.csv')
imu_df = pd.read_csv('imu_log.csv')
vision_df = pd.read_csv('vision_log.csv')

# %%
df['timestamp'] = df['timestamp'] - df['timestamp'].min()

# %%
imu_df.head()
# Out:
#       timestamp        ax        ay        az        gx        gy        gz
# 0  1.770312e+09 -0.041613  0.095833  9.759695  0.001894  0.003180 -0.000230
# 1  1.770312e+09 -0.041574  0.091802  9.755643  0.001894  0.002966  0.000196
# 2  1.770312e+09 -0.043643  0.095850  9.763672  0.002320  0.003393  0.000196
# 3  1.770312e+09 -0.041675  0.095862  9.763701  0.001894  0.002753  0.000196
# 4  1.770312e+09 -0.041699  0.091861  9.763655  0.001894  0.002540  0.001262

# %%
# %matplotlib ipympl
plt.close('all')

fig, ax = plt.subplots(1, 1)
for col_name in ['px', 'py', 'pz']:
    ax.plot(df['timestamp'], df[col_name], marker=None, label=col_name)

ax.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
plt.close('all')

fig, ax = plt.subplots(1, 1)
for col_name in ['b_ax', 'b_ay', 'b_az']:
    ax.plot(df['timestamp'], df[col_name], marker=None, label=col_name)

ax.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
plt.close('all')

fig, ax = plt.subplots(1, 1)
for col_name in ['qx', 'qy', 'qz']:
    ax.plot(df['timestamp'], df[col_name], marker=None, label=col_name)

ax.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
for col_name in 'ax', 'ay', 'az':
    print(f"{col_name}: mean: {imu_df[col_name].mean()}, std: {imu_df[col_name].std()}")
# Out:
# ax: mean: -0.040908281755196306, std: 0.0039719001517308965
# ay: mean: 0.09234559930715937, std: 0.003180046348584251
# az: mean: 9.759221608545035, std: 0.00334724568167955
