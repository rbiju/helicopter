# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('log.csv')
imu_df = pd.read_csv('imu_log.csv')
vision_df = pd.read_csv('vision_log.csv')

# %%
df['timestamp'] = df['timestamp'] - df['timestamp'].min()

# %%
df.head()
# Out:
#    timestamp   event        qw        qx        qy        qz        px  \
# 0   0.000000  vision  0.999891  0.008739  0.011866  0.000000  0.000000
# 1   0.016012  vision  0.999891  0.008739  0.011866  0.000000  0.000000
# 2   0.042059     imu  0.999891  0.008738  0.011894  0.000024 -0.000000
# 3   0.046886     imu  0.999891  0.008738  0.011901  0.000037 -0.000001
# 4   0.048032  vision  0.999889  0.008931  0.011956 -0.000100 -0.000808
#
#          py        pz        vx        vy        vz  b_ax  b_ay      b_az  \
# 0  0.000000  0.000000  0.000000  0.000000  0.000000  -0.0   0.0 -0.015715
# 1  0.000000  0.000000  0.000000  0.000000  0.000000  -0.0   0.0 -0.015715
# 2  0.000002  0.000002 -0.000051  0.000221  0.000284  -0.0   0.0 -0.015715
# 3  0.000003  0.000004 -0.000046  0.000315  0.000379  -0.0   0.0 -0.015715
# 4 -0.000026  0.000051 -0.019829 -0.000447  0.000404   0.0   0.0 -0.015715
#
#        b_gx      b_gy      b_gz
# 0  0.001151  0.000204  0.000061
# 1  0.001151  0.000204  0.000061
# 2  0.001151  0.000204  0.000061
# 3  0.001151  0.000204  0.000061
# 4  0.001151  0.000204  0.000061

# %%
# %matplotlib ipympl
plt.close('all')

fig, ax = plt.subplots(1, 1)
for col_name in ['px', 'py', 'pz']:
    ax.plot(df['timestamp'], df[col_name], marker=None, label=col_name)

ax.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
plt.close('all')

fig, ax = plt.subplots(1, 1)
for col_name in ['b_ax', 'b_ay', 'b_az']:
    ax.plot(df['timestamp'], df[col_name], marker=None, label=col_name)

ax.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
plt.close('all')

fig, ax = plt.subplots(1, 1)
for col_name in ['qx', 'qy', 'qz']:
    ax.plot(df['timestamp'], df[col_name], marker=None, label=col_name)

ax.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
for col_name in 'ax', 'ay', 'az':
    print(f"{col_name}: mean: {imu_df[col_name].mean()}, std: {imu_df[col_name].std()}")
# Out:
# ax: mean: -0.23339923256947828, std: 0.004213773951596521
# ay: mean: 0.18713670794734275, std: 0.003249515637907456
# az: mean: 9.80611954022428, std: 0.0034319898136064217
