# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('log.csv')
imu_df = pd.read_csv('imu_log.csv')
vision_df = pd.read_csv('vision_log.csv')

# %%
df['timestamp'] = df['timestamp'] - df['timestamp'].min()

# %%
imu_df['timestamp'] = imu_df['timestamp'] - imu_df['timestamp'].min()

# %%
imu_df.head()
# Out:
#    timestamp        ax        ay        az        gx        gy        gz
# 0   0.000000  0.148250  0.057531  9.783585  0.001900  0.001261 -0.000860
# 1   0.004930  0.142377  0.065507  9.787571  0.002113  0.001475  0.000844
# 2   0.009862  0.142350  0.057512  9.779479  0.001687  0.001475 -0.001925
# 3   0.014793  0.148255  0.057543  9.775570  0.002539  0.000835 -0.000434
# 4   0.019724  0.152188  0.057553  9.779643  0.002113  0.001048 -0.000434

# %%
tmp = df[df['timestamp'] > 2.0]
tmp.head(100)
# Out:
#      timestamp   event        qx        qy        qz        qw        px  \
# 517   2.000644  vision  0.002111 -0.006081  0.001239  0.999979  0.000251
# 518   2.002379     imu  0.002111 -0.006078  0.001239  0.999979  0.000264
# 519   2.007310     imu  0.002110 -0.006074  0.001242  0.999979  0.000277
# 520   2.012241     imu  0.002109 -0.006069  0.001244  0.999979  0.000290
# 521   2.017027  vision  0.002134 -0.006089  0.001202  0.999978  0.000240
# ..         ...     ...       ...       ...       ...       ...       ...
# 612   2.361161  vision  0.001535 -0.006241  0.001622  0.999978  0.000202
# 613   2.362337     imu  0.001534 -0.006240  0.001623  0.999978  0.000208
# 614   2.367269     imu  0.001532 -0.006236  0.001627  0.999978  0.000214
# 615   2.372200     imu  0.001529 -0.006235  0.001632  0.999978  0.000221
# 616   2.377131     imu  0.001526 -0.006231  0.001638  0.999978  0.000228
#
#            py        pz        vx        vy        vz      b_ax      b_ay  \
# 517 -0.000626  0.001229  0.002478  0.000252  0.000436  0.006428  0.012878
# 518 -0.000625  0.001231  0.002608  0.000270  0.000411  0.006428  0.012878
# 519 -0.000623  0.001233  0.002652  0.000266  0.000402  0.006428  0.012878
# 520 -0.000622  0.001235  0.002715  0.000283  0.000375  0.006428  0.012878
# 521 -0.000596  0.001220  0.002395  0.000276  0.000375  0.006433  0.012628
# ..        ...       ...       ...       ...       ...       ...       ...
# 612 -0.000599  0.001224  0.001159  0.010203 -0.000171  0.006743  0.011530
# 613 -0.000548  0.001223  0.001233  0.010282 -0.000158  0.006743  0.011530
# 614 -0.000498  0.001223  0.001278  0.010362 -0.000146  0.006743  0.011530
# 615 -0.000446  0.001222  0.001392  0.010462 -0.000172  0.006743  0.011530
# 616 -0.000394  0.001221  0.001457  0.010542 -0.000160  0.006743  0.011530
#
#          b_az      b_gx      b_gy      b_gz
# 517 -0.024747  0.002338 -0.000692 -0.001986
# 518 -0.024747  0.002338 -0.000692 -0.001986
# 519 -0.024747  0.002338 -0.000692 -0.001986
# 520 -0.024747  0.002338 -0.000692 -0.001986
# 521 -0.024747  0.002318 -0.000669 -0.001942
# ..        ...       ...       ...       ...
# 612 -0.024638  0.003062 -0.000177 -0.002140
# 613 -0.024638  0.003062 -0.000177 -0.002140
# 614 -0.024638  0.003062 -0.000177 -0.002140
# 615 -0.024638  0.003062 -0.000177 -0.002140
# 616 -0.024638  0.003062 -0.000177 -0.002140
#
# [100 rows x 18 columns]

# %%
# %matplotlib ipympl
plt.close('all')

fig, ax = plt.subplots(1, 1)
for col_name in ['px', 'py', 'pz']:
    ax.plot(df['timestamp'], df[col_name], marker=None, label=col_name)

ax.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
plt.close('all')

fig, ax = plt.subplots(1, 1)
for col_name in ['b_ax', 'b_ay', 'b_az']:
    ax.plot(df['timestamp'], df[col_name], marker=None, label=col_name)

ax.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
plt.close('all')

fig, ax = plt.subplots(1, 1)
for col_name in ['b_gx', 'b_gy', 'b_gz']:
    ax.plot(df['timestamp'], df[col_name], marker=None, label=col_name)

ax.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
plt.close('all')

fig, ax = plt.subplots(1, 1)
for col_name in ['qx', 'qy', 'qz']:
    ax.plot(df['timestamp'], df[col_name], marker=None, label=col_name)

ax.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
for col_name in 'ax', 'ay', 'az':
    print(f"{col_name}: mean: {imu_df[col_name].mean()}, std: {imu_df[col_name].std()}")
# Out:
# ax: mean: 0.14423445574771107, std: 0.0033733613446431457
# ay: mean: 0.05734823397761953, std: 0.0031398972533984828
# az: mean: 9.810173885045778, std: 0.003407218365146302

# %%
for col_name in 'gx', 'gy', 'gz':
    print(f"{col_name}: mean: {imu_df[col_name].mean()}, std: {imu_df[col_name].std()}")
# Out:
# gx: mean: 0.0003622136317395727, std: 0.0003772980706975216
# gy: mean: 0.00019266632756866732, std: 0.00038303308040928184
# gz: mean: 0.0009458992878942014, std: 0.0007869100305374105
