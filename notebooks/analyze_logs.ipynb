# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('log.csv')
imu_df = pd.read_csv('imu_log.csv')
vision_df = pd.read_csv('vision_log.csv')

# %%
df['timestamp'] = df['timestamp'] - df['timestamp'].min()

# %%
df.head()
# Out:
#    timestamp   event        qw        qx        qy        qz        px  \
# 0   0.000000  vision  0.999987 -0.004962 -0.000577 -0.000484 -0.000001
# 1   0.048182     imu  0.999987 -0.004962 -0.000577 -0.000484 -0.000001
# 2   0.050197  vision  0.999974 -0.007138 -0.000841 -0.000220 -0.000016
# 3   0.053240     imu  0.999974 -0.007129 -0.000853 -0.000219 -0.000017
# 4   0.058297     imu  0.999974 -0.007123 -0.000864 -0.000214 -0.000018
#
#          py        pz        vx        vy        vz  b_ax  b_ay      b_az  \
# 0 -0.000000  0.000000  0.000000  0.000000  0.000000  -0.0   0.0 -0.013719
# 1 -0.000000  0.000000  0.000000  0.000000  0.000000  -0.0   0.0 -0.013719
# 2 -0.000020  0.000014  0.000000  0.000000  0.000000  -0.0   0.0 -0.013719
# 3 -0.000016  0.000014 -0.000212  0.001659 -0.000079  -0.0   0.0 -0.013719
# 4 -0.000004  0.000013 -0.000426  0.003316 -0.000158  -0.0   0.0 -0.013719
#
#       b_gx      b_gy     b_gz
# 0 -0.00135  0.004439  0.00196
# 1 -0.00135  0.004439  0.00196
# 2 -0.00135  0.004439  0.00196
# 3 -0.00135  0.004439  0.00196
# 4 -0.00135  0.004439  0.00196

# %%
# %matplotlib ipympl
plt.close('all')

fig, ax = plt.subplots(1, 1)
for col_name in ['px', 'py', 'pz']:
    ax.plot(df['timestamp'], df[col_name], marker=None, label=col_name)

ax.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
df['py'].mean()
# Out:
# np.float64(1.5685152884270868)

# %%
for col_name in 'ax', 'ay', 'az':
    print(f"{col_name}: mean: {imu_df[col_name].mean()}, std: {imu_df[col_name].std()}")
# Out:
# ax: mean: 0.009464494505494504, std: 0.004015853158782759
# ay: mean: 0.18852217867317866, std: 0.0033606188978297607
# az: mean: 9.776193807488806, std: 0.0034648827515604413
