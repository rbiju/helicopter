# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('log.csv')
imu_df = pd.read_csv('imu_log.csv')
vision_df = pd.read_csv('vision_log.csv')

# %%
df['timestamp'] = df['timestamp'] - df['timestamp'].min()

# %%
imu_df['timestamp'] = imu_df['timestamp'] - imu_df['timestamp'].min()

# %%
imu_df.head()
# Out:
#    timestamp        ax        ay        az        gx        gy        gz
# 0   0.000000  0.132485  0.053437  9.799313  0.003817  0.000410  0.000204
# 1   0.004969  0.136446  0.061449  9.807470  0.002966 -0.000016 -0.000009
# 2   0.009939  0.136433  0.057451  9.803424  0.004031  0.000410  0.001269
# 3   0.014909  0.132491  0.057417  9.815381  0.003817 -0.000016  0.000843
# 4   0.019880  0.126588  0.057392  9.815282  0.003604  0.000197 -0.000861

# %%
df.head()
# Out:
#    timestamp   event        qx        qy        qz        qw        px  \
# 0   0.000000  vision  0.002219 -0.007389  0.000951  0.999970 -0.000000
# 1   0.016359  vision  0.002588 -0.007308  0.000483  0.999970 -0.000000
# 2   0.042386     imu  0.002595 -0.007314  0.000481  0.999970 -0.000000
# 3   0.047355     imu  0.002599 -0.007321  0.000479  0.999970 -0.000001
# 4   0.049060  vision  0.002888 -0.007256  0.000378  0.999969  0.000002
#
#          py        pz        vx        vy        vz      b_ax      b_ay  \
# 0 -0.000000  0.000000  0.000000  0.000000  0.000000 -0.000226 -0.000064
# 1 -0.000000  0.000000  0.000000  0.000000  0.000000 -0.000226 -0.000064
# 2  0.000000  0.000000 -0.000054  0.000014  0.000045 -0.000226 -0.000064
# 3  0.000000  0.000001 -0.000089  0.000066  0.000130 -0.000226 -0.000064
# 4 -0.000001 -0.000000  0.000182 -0.000116  0.000015 -0.000258 -0.000049
#
#        b_az      b_gx      b_gy      b_gz
# 0 -0.015287  0.001196  0.002742  0.000864
# 1 -0.015287  0.001196  0.002742  0.000864
# 2 -0.015287  0.001196  0.002742  0.000864
# 3 -0.015287  0.001196  0.002742  0.000864
# 4 -0.015282  0.001045  0.002698  0.000960

# %%
# %matplotlib ipympl
plt.close('all')

fig, ax = plt.subplots(1, 1)
for col_name in ['px', 'py', 'pz']:
    ax.plot(df['timestamp'], df[col_name], marker=None, label=col_name)

ax.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
plt.close('all')

fig, ax = plt.subplots(1, 1)
for col_name in ['b_ax', 'b_ay', 'b_az']:
    ax.plot(df['timestamp'], df[col_name], marker=None, label=col_name)

ax.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
plt.close('all')

fig, ax = plt.subplots(1, 1)
for col_name in ['b_gx', 'b_gy', 'b_gz']:
    ax.plot(df['timestamp'], df[col_name], marker=None, label=col_name)

ax.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
plt.close('all')

fig, ax = plt.subplots(1, 1)
for col_name in ['qx', 'qy', 'qz']:
    ax.plot(df['timestamp'], df[col_name], marker=None, label=col_name)

ax.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
for col_name in 'ax', 'ay', 'az':
    print(f"{col_name}: mean: {imu_df[col_name].mean()}, std: {imu_df[col_name].std()}")
# Out:
# ax: mean: 0.12951539574898785, std: 0.004340474016884374
# ay: mean: 0.05707195344129555, std: 0.0032458755398381894
# az: mean: 9.810047049595143, std: 0.003599847100852104

# %%
for col_name in 'gx', 'gy', 'gz':
    print(f"{col_name}: mean: {imu_df[col_name].mean()}, std: {imu_df[col_name].std()}")
# Out:
# gx: mean: 0.0037968744939271258, std: 0.00038186971690115347
# gy: mean: 0.0001916103238866397, std: 0.00041286912313908585
# gz: mean: 0.0009067732793522266, std: 0.0007528958152538253
