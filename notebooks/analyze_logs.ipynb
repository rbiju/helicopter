# %%
import pandas as pd

# %%
df = pd.read_csv('log.csv')
imu_df = pd.read_csv('imu_log.csv')
imu_vision = pd.read_csv('vision_log.csv')

# %%
imu_df.head()
# Out:
#       timestamp        ax        ay        az        gx        gy        gz
# 0  1.769715e+09  0.113361  0.085433  9.797688  0.003179  0.001046  0.002114
# 1  1.769715e+09  0.083640  0.070199  9.812717  0.001048  0.009568  0.002114
# 2  1.769715e+09  0.032057  0.054851  9.797761  0.001048  0.010633  0.006376
# 3  1.769715e+09  0.017021  0.054712  9.827907 -0.000016  0.010633 -0.002144
# 4  1.769715e+09  0.032259  0.069883  9.782860  0.003179  0.001046  0.002114
