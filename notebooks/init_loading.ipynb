# %%
import numpy as np
from scipy.spatial.transform import Rotation

# %%
camera_quat = Rotation.from_rotvec(np.array([-0.31031, 15.377, 0]), degrees=True)
marker_rotation = Rotation.from_rotvec(np.array([    -2.7624,      -11.95,      5.7437]), degrees=True)
